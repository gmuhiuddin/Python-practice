# %%
import pandas as pd
import seaborn as sb
import numpy as np

# %%
comments = pd.read_csv("Takeout/YouTube and YouTube Music/comments/comments.csv")

# %%
comments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Comment ID                5 non-null      object
#  1   Channel ID                5 non-null      object
#  2   Comment Create Timestamp  5 non-null      object
#  3   Price                     5 non-null      int64
#  4   Parent Comment ID         1 non-null      object
#  5   Video ID                  5 non-null      object
#  6   Comment Text              5 non-null      object
# dtypes: int64(1), object(6)
# memory usage: 412.0+ bytes

# %%
comments.shape
# Out:
# (5, 7)

# %%
comments.loc[[True, False, True, False, 1], "Parent Comment ID":"Comment Text"]
# Out:
#             Parent Comment ID     Video ID  \
# 1                         NaN  B8_fYSn_RJM
# 0  UgxKLMsQEzSpfYsnold4AaABAg  B8_fYSn_RJM
# 1                         NaN  B8_fYSn_RJM
# 0  UgxKLMsQEzSpfYsnold4AaABAg  B8_fYSn_RJM
# 1                         NaN  B8_fYSn_RJM
#
#                                         Comment Text
# 1  {"text":"Sir I think ya djo connectDb ka func ...
# 0  {"text":"@pefitoc8971","mention":{"externalCha...
# 1  {"text":"Sir I think ya djo connectDb ka func ...
# 0  {"text":"@pefitoc8971","mention":{"externalCha...
# 1  {"text":"Sir I think ya djo connectDb ka func ...

# %%
watch_histroy = pd.read_json("watch-history.json")

# %%
watch_histroy.head()
# Out:
#     header                                              title  \
# 0  YouTube    Watched id3231 lowestcost 1920x1080 7s ur en v1
# 1  YouTube    Watched Domains for Your Website | Hostinger.pk
# 2  YouTube  Watched Manqabat Ameer Hamza - Sarkar Ki Nazro...
# 3  YouTube  Watched New Stronger Pepsi x KAMAAAL Taste | K...
# 4  YouTube  Watched Kya Bataun Ke Kiya Madina Hai | Allama...
#
#                                       titleUrl  \
# 0  https://www.youtube.com/watch?v=-6V7tkiUjSA
# 1  https://www.youtube.com/watch?v=gVdN5k5cUEU
# 2  https://www.youtube.com/watch?v=yfahmPu_RUg
# 3  https://www.youtube.com/watch?v=tCmirzDuEK0
# 4  https://www.youtube.com/watch?v=asEIL8CmUqk
#
#                                            subtitles         description  \
# 0  [{'name': 'Yango Group', 'url': 'https://www.y...  Watched at 6:58 PM
# 1                                                NaN  Watched at 8:22 PM
# 2  [{'name': 'Sheikhani Studio ', 'url': 'https:/...                 NaN
# ...

# %%
watch_histroy.shape
# Out:
# (37900, 9)

# %%
watch_histroy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37900 entries, 0 to 37899
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   header            37900 non-null  object
#  1   title             37900 non-null  object
#  2   titleUrl          37882 non-null  object
#  3   subtitles         34362 non-null  object
#  4   description       396 non-null    object
#  5   time              37900 non-null  object
#  6   products          37900 non-null  object
#  7   details           2109 non-null   object
#  8   activityControls  37900 non-null  object
# dtypes: object(9)
# memory usage: 2.6+ MB

# %%
watch_histroy.title=watch_histroy.title.apply(lambda x: x.lower())

# %%
watch_histroy.loc[0:0, "title"] = "girl"

# %%
watch_histroy.iloc[0:1]
# Out:
#     header title                                     titleUrl  \
# 0  YouTube  girl  https://www.youtube.com/watch?v=-6V7tkiUjSA
#
#                                            subtitles         description  \
# 0  [{'name': 'Yango Group', 'url': 'https://www.y...  Watched at 6:58 PM
#
#                        time   products                        details  \
# 0  2025-02-19T15:22:44.006Z  [YouTube]  [{'name': 'From Google Ads'}]
#
#                                     activityControls
# 0  [YouTube watch history, Web & App Activity, Yo...

# %%
watch_histroy
# Out:
#         header                                              title  \
# 0      YouTube                                               girl
# 1      YouTube    watched domains for your website | hostinger.pk
# 2      YouTube  watched manqabat ameer hamza - sarkar ki nazro...
# 3      YouTube  watched new stronger pepsi x kamaaal taste | k...
# 4      YouTube  watched kya bataun ke kiya madina hai | allama...
# ...        ...                                                ...
# 37895  YouTube  watched school😢#aesthetic #cool #schoollife#sc...
# 37896  YouTube                  watched this night is sparkling ✨
# 37897  YouTube  watched beautiful girl with bike #viralvideo #...
# 37898  YouTube  watched #trynottolaugh #memes #minecraft #mine...
# 37899  YouTube  watched skeletal muscles lecture! are you read...
#
#                                           titleUrl  \
# 0      https://www.youtube.com/watch?v=-6V7tkiUjSA
# 1      https://www.youtube.com/watch?v=gVdN5k5cUEU
# ...

# %%
watch_histroy[(watch_histroy.title.str.contains(" cow ")) & (watch_histroy.title.str.contains(""))]
# Out:
#         header                                              title  \
# 6944   YouTube  watched cow ne zx10r dak kar pagal ho gaya #sh...
# 16117  YouTube  watched cow attack on superbike. full video on...
# 17206  YouTube                 watched how to fix a bloated cow 🐮
# 18820  YouTube  watched the cow pooped on the bird, and then t...
# 20447  YouTube         watched this cow uses milk packets #shorts
# 29090  YouTube         watched amusement cow 🐄 animal beautifully
# 30125  YouTube  watched || that's why we worship cow as our mo...
# 31230  YouTube  watched cow was trying to find who made the be...
#
#                                           titleUrl  \
# 6944   https://www.youtube.com/watch?v=-VBAeS4Z30s
# 16117  https://www.youtube.com/watch?v=Me_2lm7ZeEU
# 17206  https://www.youtube.com/watch?v=IMsReCqB-Qs
# 18820  https://www.youtube.com/watch?v=ftKzU2JSvP0
# 20447  https://www.youtube.com/watch?v=eWt262fNOcc
# 29090  https://www.youtube.com/watch?v=2kTb0WgXJgU
# ...
