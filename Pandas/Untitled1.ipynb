# %%
import pandas as pd

# %%
data = pd.DataFrame({"food": ["bacon", "pulled pork", "bacon",
 "pastrami", "corned beef", "bacon",
  "pastrami", "honey ham", "nova lox"],
 "ounces": [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})

# %%
meat_to_animal = {
 "bacon": "pig",
 "pulled pork": "pig",
 "pastrami": "cow",
 "corned beef": "cow",
 "honey ham": "pig",
 "nova lox": "salmon"
}

# %%
data.head()
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     pastrami     6.0
# 4  corned beef     7.5

# %%
data["Animal_type"] = data["food"].map(meat_to_animal)

# %%
data.head()
# Out:
#           food  ounces Animal_type
# 0        bacon     4.0         pig
# 1  pulled pork     3.0         pig
# 2        bacon    12.0         pig
# 3     pastrami     6.0         cow
# 4  corned beef     7.5         cow

# %%
weight_data = pd.read_csv("weight-height.csv")

# %%
weight_data.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
import seaborn as sb

# %%
cat_of_weight = pd.cut(weight_data.Height, [50, 55, 60, 65, 70, 75, 80])

# %%
sb.barplot(cat_of_weight.value_counts())
# Out:
# <Axes: xlabel='Height', ylabel='count'>

# %%
cat_of_weight.value_counts()
# Out:
# Height
# (65, 70]    4312
# (60, 65]    3397
# (70, 75]    1793
# (55, 60]     410
# (75, 80]      85
# (50, 55]       3
# Name: count, dtype: int64

# %% [markdown]
# ## this mean () close intervals and (0, 1]

# %%
data = {
    'Employee id': [10, 20, 15, 25, 30],
    'Gender': ['M', 'F', 'F', 'M', 'F'],
    'Remarks': ['Good', 'Nice', 'Good', 'Great', 'Nice']
}

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    Employee id Gender Remarks
# 0           10      M    Good
# 1           20      F    Nice
# 2           15      F    Good
# 3           25      M   Great
# 4           30      F    Nice

# %%
df.Gender=df.Gender.map({"M": "Male", "F": "Female"})

# %%
print(f"Employee Data: \n{df}")
# Out:
# Employee Data:
#    Employee id  Gender Remarks
# 0           10    Male    Good
# 1           20  Female    Nice
# 2           15  Female    Good
# 3           25    Male   Great
# 4           30  Female    Nice

# %%
encoded_data = pd.get_dummies(df, dtype="int")

# %%
encoded_data.shape
# Out:
# (5, 6)

# %%
sales_men_data_1 = pd.read_excel("test_data.xlsx")

# %%
sales_men_data_1.shape
# Out:
# (9, 5)

# %%
sales_men_data_1_encoded = pd.get_dummies(sales_men_data_1, dtype="int")

# %%
sales_men_data_1_encoded
# Out:
#    sales_man_id  product_id  sales_man_name_Abdullah  sales_man_name_Asad  \
# 0             1         123                        0                    1
# 1             2         123                        0                    0
# 2             3         145                        0                    0
# 3             4         567                        0                    0
# 4             5         234                        0                    0
# 5             6         234                        0                    0
# 6             7         567                        0                    0
# 7             8         345                        0                    0
# 8             9         123                        1                    0
#
#    sales_man_name_Farjad  sales_man_name_Fatima  sales_man_name_Hassan  \
# 0                      0                      0                      0
# 1                      0                      0                      0
# ...

# %%
data1 = pd.read_excel("test_data-2.xlsx", sheet_name=0)
data2 = pd.read_excel("test_data-2.xlsx", sheet_name=1)
data3 = pd.read_excel("test_data-2.xlsx", sheet_name=2)

# %%
pd.merge(data1, data2, on="sales_man_name", how="inner")
# Out:
#    sales_man_id_x sales_man_name sales_man_city_x  product_id_x manager_x  \
# 0               1           Asad          Karachi           123     Jawed
# 1               1           Asad          Karachi           123     Jawed
# 2               1           Asad          Karachi           123     Jawed
#
#    sales_man_id_y sales_man_city_y  product_id_y manager_y  Experience
# 0               4           Lahore           567     Najam           5
# 1             101        Hyderabad           432     Jawed           4
# 2             101        Hyderabad           432     Jawed           5

# %%
data1.head()
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed

# %%
data2.shape
# Out:
# (11, 6)

# %%
data2.head()
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager  Experience
# 0             1          Ahmed        Karachi         123   Jawed           2
# 1            22           Umer         Lahore         123   Jawed           3
# 2            33        Huzaifa        Karachi         145   Najam           4
# 3             4           Asad         Lahore         567   Najam           5
# 4            55        Hussain      Hyderabad         234   Jawed           6

# %%
pd.merge(data2, data3, on="sales_man_name", how="outer")
# Out:
#     sales_man_id sales_man_name sales_man_city  product_id manager  \
# 0            1.0          Ahmed        Karachi       123.0   Jawed
# 1           66.0            Ali      Hyderabad       234.0  Faisal
# 2           99.0            Ali        Karachi       123.0  Faisal
# 3            NaN          Almas            NaN         NaN     NaN
# 4            4.0           Asad         Lahore       567.0   Najam
# 5          101.0           Asad      Hyderabad       432.0   Jawed
# 6          101.0           Asad      Hyderabad       432.0   Jawed
# 7            NaN          Fahan            NaN         NaN     NaN
# 8            NaN         Fatima            NaN         NaN     NaN
# 9            NaN         Hassan            NaN         NaN     NaN
# 10          55.0        Hussain      Hyderabad       234.0   Jawed
# 11          33.0        Huzaifa        Karachi       145.0   Najam
# 12           NaN         Kashif            NaN         NaN     NaN
# ...

# %%
pd.merge(data2,data1,how="left")
# Out:
#     sales_man_id sales_man_name sales_man_city  product_id manager  Experience
# 0              1          Ahmed        Karachi         123   Jawed           2
# 1             22           Umer         Lahore         123   Jawed           3
# 2             33        Huzaifa        Karachi         145   Najam           4
# 3              4           Asad         Lahore         567   Najam           5
# 4             55        Hussain      Hyderabad         234   Jawed           6
# 5             66            Ali      Hyderabad         234  Faisal           7
# 6             77          Sadaf         Lahore         567  Faisal           8
# 7             88          Kiran        Karachi         345   Najam           9
# 8             99            Ali        Karachi         123  Faisal           1
# 9            101           Asad      Hyderabad         432   Jawed           4
# 10           101           Asad      Hyderabad         432   Jawed           5

# %%
sales_data = pd.read_excel("")
