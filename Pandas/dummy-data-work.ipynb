# %% [markdown]
# # Data Wranglling

# %%
import pandas as pd

# %%
data = pd.read_excel("test_data.xlsx", sheet_name=0)
data1 = pd.read_excel("test_data.xlsx", sheet_name=1)
data2 = pd.read_excel("test_data.xlsx", sheet_name=2)

# %%
data.head()
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed

# %%
data1.head()
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager  Experience
# 0             1          Ahmed        Karachi         123   Jawed           2
# 1            22           Umer         Lahore         123   Jawed           3
# 2            33        Huzaifa        Karachi         145   Najam           4
# 3             4           Asad         Lahore         567   Najam           5
# 4            55        Hussain      Hyderabad         234   Jawed           6

# %%
data2.head()
# Out:
#   sales_man_name Region   Sales  Amount
# 0           Asad       A    100   100000
# 1        Hussain       B    300   450000
# 2            Ali       C    234   125000
# 3           Sana       D    231   652000
# 4         Fatima       E    324   145000

# %%
pd.concat([data, data1]).reset_index()
# Out:
#     index  sales_man_id sales_man_name sales_man_city  product_id manager  \
# 0       0             1           Asad        Karachi         123   Jawed
# 1       1             2         Sumair         Lahore         123   Jawed
# 2       2             3         Farjad        Karachi         145   Najam
# 3       3             4         Hassan         Lahore         567   Najam
# 4       4             5          Nasir      Hyderabad         234   Jawed
# 5       5             6         Kashif      Hyderabad         234  Faisal
# 6       6             7           Sana         Lahore         567  Faisal
# 7       7             8         Fatima        Karachi         345   Najam
# 8       8             9       Abdullah        Karachi         123  Faisal
# 9       0             1          Ahmed        Karachi         123   Jawed
# 10      1            22           Umer         Lahore         123   Jawed
# 11      2            33        Huzaifa        Karachi         145   Najam
# ...

# %%
pd.concat([data, data1], axis=1).reset_index()
# Out:
#     index  sales_man_id sales_man_name sales_man_city  product_id manager  \
# 0       0           1.0           Asad        Karachi       123.0   Jawed
# 1       1           2.0         Sumair         Lahore       123.0   Jawed
# 2       2           3.0         Farjad        Karachi       145.0   Najam
# 3       3           4.0         Hassan         Lahore       567.0   Najam
# 4       4           5.0          Nasir      Hyderabad       234.0   Jawed
# 5       5           6.0         Kashif      Hyderabad       234.0  Faisal
# 6       6           7.0           Sana         Lahore       567.0  Faisal
# 7       7           8.0         Fatima        Karachi       345.0   Najam
# 8       8           9.0       Abdullah        Karachi       123.0  Faisal
# 9       9           NaN            NaN            NaN         NaN     NaN
# 10     10           NaN            NaN            NaN         NaN     NaN
#
#     sales_man_id sales_man_name sales_man_city  product_id manager  Experience
# ...

# %%
pd.merge(data, data1, how="inner", on="sales_man_id")
# Out:
#    sales_man_id sales_man_name_x sales_man_city_x  product_id_x manager_x  \
# 0             1             Asad          Karachi           123     Jawed
# 1             4           Hassan           Lahore           567     Najam
#
#   sales_man_name_y sales_man_city_y  product_id_y manager_y  Experience
# 0            Ahmed          Karachi           123     Jawed           2
# 1             Asad           Lahore           567     Najam           5
